# %% [markdown]
# <a href="https://colab.research.google.com/github/trailmarkerlib/exploreDataPython/blob/master/caasi_grief_to_action_python_workshop_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CAASI Grief to Action Python Workshop 1
#
# #### Pittsburgh Police Arrest Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from pandas import json_normalize
import json
import requests

# %%
url = 'https://data.wprdc.org/api/3/action/datastore_search?resource_id=e03a89dd-134a-4ee8-a2bd-62c40aeebc6f'

data = json.loads(requests.get(url).text)

# %%
data['result']['records']
# Out:
# [{'_id': 1,
#   'PK': '1975272',
#   'CCR': '16158872',
#   'AGE': 42,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-24T12:20:00',
#   'ARRESTLOCATION': '4700 Block Centre AV Pittsburgh, PA 15213',
#   'OFFENSES': '3929 Retail Theft.',
#   'INCIDENTLOCATION': '4700 Block Centre AV Pittsburgh, PA 15213',
#   'INCIDENTNEIGHBORHOOD': 'Bloomfield',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '804',
#   'COUNCIL_DISTRICT': '8',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.94927741,
#   'Y': 40.45255125},
#  {'_id': 2,
#   'PK': '1974456',
#   'CCR': '16144120',
#   'AGE': 31,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-03T14:55:00',
#   'ARRESTLOCATION': '4200 Block Steubenville PKE Pittsburgh, PA 15205',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance',
#   'INCIDENTLOCATION': '4200 Block Steubenville PKE Pittsburgh, PA 15205',
#   'INCIDENTNEIGHBORHOOD': 'Outside City',
#   'INCIDENTZONE': 'OSC',
#   'INCIDENTTRACT': '5599',
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': -80.08801806,
#   'Y': 40.44013633},
#  {'_id': 3,
#   'PK': '1974466',
#   'CCR': '16144165',
#   'AGE': 63,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-03T16:45:00',
#   'ARRESTLOCATION': '900 Block Freeport RD Fox Chapel, PA 15238',
#   'OFFENSES': '3929 Retail Theft.',
#   'INCIDENTLOCATION': '900 Block Freeport RD Fox Chapel, PA 15238',
#   'INCIDENTNEIGHBORHOOD': 'Westwood',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '2811',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.89180294,
#   'Y': 40.48662475},
#  {'_id': 4,
#   'PK': '1974550',
#   'CCR': '16145257',
#   'AGE': 25,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-05T02:36:00',
#   'ARRESTLOCATION': 'Foreland ST & Cedar AV Pittsburgh, PA 15212',
#   'OFFENSES': '5503 Disorderly Conduct. / 5505 Public Drunkenness',
#   'INCIDENTLOCATION': 'Foreland ST & Cedar AV Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00193876,
#   'Y': 40.45408043},
#  {'_id': 5,
#   'PK': '1974596',
#   'CCR': '16145962',
#   'AGE': 25,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-06T02:00:00',
#   'ARRESTLOCATION': '900 Block Woodlow ST Pittsburgh, PA 15205',
#   'OFFENSES': '2702 Aggravated Assault. / 2705 Recklessy Endangering Another Person. / 3925 Receiving Stolen Property. / 4304(a)(1) Endangering Welfare of Children.',
#   'INCIDENTLOCATION': '900 Block Woodlow ST Pittsburgh, PA 15205',
#   'INCIDENTNEIGHBORHOOD': 'Crafton Heights',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '2814',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.05220414,
#   'Y': 40.44589982},
#  {'_id': 6,
#   'PK': '1974556',
#   'CCR': '16144301',
#   'AGE': 45,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-15T13:30:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '3929 Retail Theft.',
#   'INCIDENTLOCATION': '800 Block Hazelwood AV Pittsburgh, PA 15217',
#   'INCIDENTNEIGHBORHOOD': 'Greenfield',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1517',
#   'COUNCIL_DISTRICT': '5',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.92923755,
#   'Y': 40.41969887},
#  {'_id': 7,
#   'PK': '1974628',
#   'CCR': '16147655',
#   'AGE': 29,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-16T13:00:00',
#   'ARRESTLOCATION': '2300 Block Pioneer AV Pittsburgh, PA 15226',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': '2300 Block Pioneer AV Pittsburgh, PA 15226',
#   'INCIDENTNEIGHBORHOOD': 'Brookline',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '1919',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.02035721,
#   'Y': 40.40003652},
#  {'_id': 8,
#   'PK': '1974607',
#   'CCR': '16146037',
#   'AGE': 21,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-16T04:25:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '2701 Simple Assault. / 5505 Public Drunkenness / 5503(a)(1) DISORDERLY CONDUCT - ENGAGE IN FIGHTING / 3304(a)(5) CRIMINAL MISCHIEF - Intentionally Damages Real Or Personal Property Of Another',
#   'INCIDENTLOCATION': '700 Block S Braddock AV Pittsburgh, PA 15221',
#   'INCIDENTNEIGHBORHOOD': 'Regent Square',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1410',
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': -79.83446229,
#   'Y': 40.39895684},
#  {'_id': 9,
#   'PK': '1974643',
#   'CCR': '16132537',
#   'AGE': 17,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-29T17:55:00',
#   'ARRESTLOCATION': '1400 Block Washington BL Pittsburgh, PA 15206',
#   'OFFENSES': '903 Criminal Conspiracy. / 3701 Robbery.',
#   'INCIDENTLOCATION': 'N Euclid AV & Broad ST Pittsburgh, PA 15206',
#   'INCIDENTNEIGHBORHOOD': 'East Liberty',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1115',
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': None,
#   'Y': None},
#  {'_id': 10,
#   'PK': '1974647',
#   'CCR': '16138646',
#   'AGE': 14,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-23T13:36:00',
#   'ARRESTLOCATION': 'Zone 2',
#   'OFFENSES': '3127 Indecent Exposure. / 3123(a)(6) IDSI with person less than 13 years of age / 3126(a)(7) Indecent assault of person under 13',
#   'INCIDENTLOCATION': 'Zone 5',
#   'INCIDENTNEIGHBORHOOD': None,
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': None,
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': None,
#   'Y': None},
#  {'_id': 11,
#   'PK': '1974696',
#   'CCR': '16149661',
#   'AGE': 30,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-11T18:00:00',
#   'ARRESTLOCATION': '7900 Block Aber RD Verona, PA 15147',
#   'OFFENSES': '2701 Simple Assault. / 3304 Criminal Mischief. / 3502 Burglary. / 3503 Criminal Trespass',
#   'INCIDENTLOCATION': '600 Block Sickles ST Pittsburgh, PA 15221',
#   'INCIDENTNEIGHBORHOOD': 'East Hills',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1306',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.8824703,
#   'Y': 40.45147202},
#  {'_id': 12,
#   'PK': '1974704',
#   'CCR': '16146903',
#   'AGE': 45,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-07T13:40:00',
#   'ARRESTLOCATION': '300 Block Newett ST Pittsburgh, PA 15210',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': '300 Block Newett ST Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Carrick',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '2901',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.99171209,
#   'Y': 40.39655765},
#  {'_id': 13,
#   'PK': '1974872',
#   'CCR': '16153543',
#   'AGE': 54,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-16T20:50:00',
#   'ARRESTLOCATION': 'East ST & East Ohio ST Pittsburgh, PA 15212',
#   'OFFENSES': '5507 Obstructing Highways and Passages.',
#   'INCIDENTLOCATION': 'East ST & East Ohio ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99783935,
#   'Y': 40.45392477},
#  {'_id': 14,
#   'PK': '1974578',
#   'CCR': '16144432',
#   'AGE': 27,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-13T15:43:00',
#   'ARRESTLOCATION': '1300 Block E Carson ST Pittsburgh, PA 15203',
#   'OFFENSES': '3921(a) Theft by Unlawful Taking or Disposition - Movable item',
#   'INCIDENTLOCATION': '1000 Block Lessing ST Pittsburgh, PA 15205',
#   'INCIDENTNEIGHBORHOOD': 'Crafton Heights',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2814',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.04968579,
#   'Y': 40.44391784},
#  {'_id': 15,
#   'PK': '1975078',
#   'CCR': '16157821',
#   'AGE': 53,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T22:09:00',
#   'ARRESTLOCATION': '400 Block Foreland ST Pittsburgh, PA 15212',
#   'OFFENSES': '5123 Contraband. / 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession / 9501 Bench Warrant',
#   'INCIDENTLOCATION': '400 Block Foreland ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.0019398,
#   'Y': 40.45413683},
#  {'_id': 16,
#   'PK': '1975102',
#   'CCR': '16156591',
#   'AGE': 18,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-21T03:50:00',
#   'ARRESTLOCATION': '2400 Block Toner ST Pittsburgh, PA 15212',
#   'OFFENSES': '903 Criminal Conspiracy. / 3701 Robbery.',
#   'INCIDENTLOCATION': 'Arch ST & W North AV Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Allegheny Center',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2204',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00862797,
#   'Y': 40.45509083},
#  {'_id': 17,
#   'PK': '1975138',
#   'CCR': '16160913',
#   'AGE': 22,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-27T02:04:00',
#   'ARRESTLOCATION': 'Middle ST & Suismon ST Pittsburgh, PA 15212',
#   'OFFENSES': '5505 Public Drunkenness / 13(a)(32) Paraphernalia - Use or Possession / 13(a)(31) Marijuana: Possession Small Amount',
#   'INCIDENTLOCATION': 'Middle ST & Suismon ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.999646,
#   'Y': 40.45536416},
#  {'_id': 18,
#   'PK': '1975141',
#   'CCR': '16160953',
#   'AGE': 23,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-27T03:25:00',
#   'ARRESTLOCATION': 'S 17th ST & Muriel ST Pittsburgh, PA 15203',
#   'OFFENSES': '6106 Firearms not to be Carried without a License. / 4303 General Lighting Requirements.',
#   'INCIDENTLOCATION': 'S 17th ST & Muriel ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98191245,
#   'Y': 40.43018096},
#  {'_id': 19,
#   'PK': '1975192',
#   'CCR': '16150754',
#   'AGE': 33,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-12T21:07:00',
#   'ARRESTLOCATION': '1500 Block Milan AV Pittsburgh, PA 15226',
#   'OFFENSES': '9501 Bench Warrant',
#   'INCIDENTLOCATION': '1500 Block Milan AV Pittsburgh, PA 15226',
#   'INCIDENTNEIGHBORHOOD': 'Brookline',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '3206',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.00580324,
#   'Y': 40.39386825},
#  {'_id': 20,
#   'PK': '1975199',
#   'CCR': '16150776',
#   'AGE': 22,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-12T20:15:00',
#   'ARRESTLOCATION': '3200 Block Faronia ST Pittsburgh, PA 15204',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance',
#   'INCIDENTLOCATION': '3200 Block Faronia ST Pittsburgh, PA 15204',
#   'INCIDENTNEIGHBORHOOD': 'Sheraden',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2022',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.06635734,
#   'Y': 40.45160189},
#  {'_id': 21,
#   'PK': '1975260',
#   'CCR': '16150804',
#   'AGE': 41,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-16T11:20:00',
#   'ARRESTLOCATION': '1100 Block W North AV Pittsburgh, PA 15233',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': '50 Block S 25th ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1609',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.96969527,
#   'Y': 40.42865113},
#  {'_id': 22,
#   'PK': '1975381',
#   'CCR': '16157283',
#   'AGE': 14,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-13T10:40:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '903 Criminal Conspiracy. / 2701 Simple Assault. / 2709(a)(1) Harassment by Physical Contact, or Attempts or Threats / 3304(a)(5) CRIMINAL MISCHIEF - Intentionally Damages Real Or Personal Property Of Another',
#   'INCIDENTLOCATION': 'Alter ST & Doolittle ST Pittsburgh, PA 15205',
#   'INCIDENTNEIGHBORHOOD': 'East Carnegie',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2805',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.07481143,
#   'Y': 40.41497073},
#  {'_id': 23,
#   'PK': '1975395',
#   'CCR': '16162377',
#   'AGE': 26,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-29T11:20:00',
#   'ARRESTLOCATION': '600 Block Smithfield ST Pittsburgh, PA 15222',
#   'OFFENSES': '3929 Retail Theft. / 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession',
#   'INCIDENTLOCATION': '600 Block Smithfield ST Pittsburgh, PA 15222',
#   'INCIDENTNEIGHBORHOOD': 'Golden Triangle/Civic Arena',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '201',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -79.99740551,
#   'Y': 40.44152525},
#  {'_id': 24,
#   'PK': '1975398',
#   'CCR': '16163197',
#   'AGE': 22,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-30T12:50:00',
#   'ARRESTLOCATION': '2000 Block Wharton ST Pittsburgh, PA 15203',
#   'OFFENSES': '3929(a)(1) Retail Theft; takes possession of, carries away, or transfers displayed merchandise',
#   'INCIDENTLOCATION': '2000 Block Wharton ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.97681333,
#   'Y': 40.43002082},
#  {'_id': 25,
#   'PK': '1975401',
#   'CCR': '16127119',
#   'AGE': 22,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-14T17:00:00',
#   'ARRESTLOCATION': '900 Block SCECOND AV Pittsburgh, PA 15219',
#   'OFFENSES': '901 Criminal Attempt / 2702 Aggravated Assault. / 2705 Recklessy Endangering Another Person. / 6106 Firearms not to be Carried without a License.',
#   'INCIDENTLOCATION': '6800 Block Thomas ST Pittsburgh, PA 15208',
#   'INCIDENTNEIGHBORHOOD': 'Point Breeze North',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1405',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.90902003,
#   'Y': 40.45372378},
#  {'_id': 26,
#   'PK': '1975410',
#   'CCR': '16164279',
#   'AGE': 15,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-31T21:29:00',
#   'ARRESTLOCATION': '2400 Block N Charles ST Pittsburgh, PA 15214',
#   'OFFENSES': '903 Criminal Conspiracy. / 3702 Robbery of Motor Vehicle. / 4910 Tampering with or Fabricating Physical Evidence. / 5104 Resisting Arrest or Other Law Enforcement. / 6110.1 Possesion of Firearm by Minor / 2701(a)(3) Simple Assault - Attempts by Physical Menace  / 6105(c)(9) Persons Not To Possess Use Manuf, Control Firearm',
#   'INCIDENTLOCATION': '2500 Block N Charles ST Pittsburgh, PA 15214',
#   'INCIDENTNEIGHBORHOOD': 'Perry South',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2614',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.01885858,
#   'Y': 40.46692217},
#  {'_id': 27,
#   'PK': '1974645',
#   'CCR': '16118337',
#   'AGE': 18,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-29T11:14:00',
#   'ARRESTLOCATION': '600 Block 1ST AV Pittsburgh, PA 15219',
#   'OFFENSES': '9015 Failure To Appear/Arrest on Attachment Order',
#   'INCIDENTLOCATION': 'S 16th ST & E Carson ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98271222,
#   'Y': 40.4288317},
#  {'_id': 28,
#   'PK': '1974658',
#   'CCR': '16143061',
#   'AGE': 18,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-02T13:45:00',
#   'ARRESTLOCATION': '1200 Block Western AV Pittsburgh, PA 15233',
#   'OFFENSES': '2501 Criminal Homicide. / 3925 Receiving Stolen Property. / 4910 Tampering with or Fabricating Physical Evidence. / 6105(a)(1) Persons not to possess, use, manufacture, control, sell or transfer firearms: Former Convict enumerated in subsection (b) / 6106 Firearms not to be Carried without a License. / 6110.2 Possesion of Firearm with Altered Mfg. Number',
#   'INCIDENTLOCATION': '1500 Block Arlington AV Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Allentown',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1803',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -79.98930113,
#   'Y': 40.41918031},
#  {'_id': 29,
#   'PK': '1974694',
#   'CCR': '16145933',
#   'AGE': 31,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-06T00:45:00',
#   'ARRESTLOCATION': 'Walter ST & Manton WY Pittsburgh, PA 15210',
#   'OFFENSES': '2702 Aggravated Assault.',
#   'INCIDENTLOCATION': '700 Block Proctor WY Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Allentown',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1803',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -79.99576971,
#   'Y': 40.42030248},
#  {'_id': 30,
#   'PK': '1975436',
#   'CCR': '16089206',
#   'AGE': 35,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-07-25T08:55:00',
#   'ARRESTLOCATION': '900 Block 2ND AV Pittsburgh, PA 15219',
#   'OFFENSES': '2701 Simple Assault. / 2707 Propulsion of Missiles  / 3304 Criminal Mischief.',
#   'INCIDENTLOCATION': 'Washington PL & 5th AV Pittsburgh, PA 15219',
#   'INCIDENTNEIGHBORHOOD': 'Golden Triangle/Civic Arena',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '201',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -79.99084692,
#   'Y': 40.43880171},
#  {'_id': 31,
#   'PK': '1975438',
#   'CCR': '16122836',
#   'AGE': 30,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-07-02T15:51:00',
#   'ARRESTLOCATION': 'General Robinson ST W & Tony Dorsett DR Pittsburgh, PA 15212',
#   'OFFENSES': '5505 Public Drunkenness / 3503.B1I DEF. TRESPASS ACTUAL COMMUNICATION / 5503(a)(4) DISORDERLY CONDUCT - HAZARDOUS/PHYS. OFF',
#   'INCIDENTLOCATION': 'General Robinson ST & Tony Dorsett DR Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'North Shore',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2205',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -80.01030287,
#   'Y': 40.44727154},
#  {'_id': 32,
#   'PK': '1975442',
#   'CCR': '16130817',
#   'AGE': 25,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-07-14T16:05:00',
#   'ARRESTLOCATION': '1300 Block Superior AV Pittsburgh, PA 15212',
#   'OFFENSES': '9501 Bench Warrant',
#   'INCIDENTLOCATION': '1300 Block Superior AV Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Marshall-Shadeland',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2704',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.02985038,
#   'Y': 40.46796892},
#  {'_id': 33,
#   'PK': '1974758',
#   'CCR': '16151002',
#   'AGE': 45,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T10:15:00',
#   'ARRESTLOCATION': '900 Block Second AV Pittsburgh, PA 15219',
#   'OFFENSES': '3929 Retail Theft.',
#   'INCIDENTLOCATION': '200 Block Atwood ST Pittsburgh, PA 15213',
#   'INCIDENTNEIGHBORHOOD': 'Central Oakland',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '405',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.95688887,
#   'Y': 40.44042041},
#  {'_id': 34,
#   'PK': '1974767',
#   'CCR': '16151393',
#   'AGE': 32,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-13T17:08:00',
#   'ARRESTLOCATION': 'Bedford AV & Herron AV Pittsburgh, PA 15219',
#   'OFFENSES': '4303 General Lighting Requirements. / 13(a)(31) Marijuana: Possession Small Amount',
#   'INCIDENTLOCATION': 'Bedford AV & Herron AV Pittsburgh, PA 15219',
#   'INCIDENTNEIGHBORHOOD': 'Middle Hill',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '501',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.9649249,
#   'Y': 40.45288317},
#  {'_id': 35,
#   'PK': '1974791',
#   'CCR': '15125202',
#   'AGE': 25,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-30T09:15:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '3921(a) Theft by Unlawful Taking or Disposition - Movable item',
#   'INCIDENTLOCATION': '2700 Block E Carson ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1609',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.96689241,
#   'Y': 40.42666614},
#  {'_id': 36,
#   'PK': '1975457',
#   'CCR': '16164458',
#   'AGE': 21,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-01T06:17:00',
#   'ARRESTLOCATION': 'Smallman ST & 14th ST Pittsburgh, PA 15222',
#   'OFFENSES': '3934 Theft from Vehicle',
#   'INCIDENTLOCATION': 'Mulberry WY & 14th ST Pittsburgh, PA 15222',
#   'INCIDENTNEIGHBORHOOD': 'Strip District',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '203',
#   'COUNCIL_DISTRICT': '7',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -79.99019085,
#   'Y': 40.44766989},
#  {'_id': 37,
#   'PK': '1975458',
#   'CCR': '16164486',
#   'AGE': 31,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-01T07:32:00',
#   'ARRESTLOCATION': 'Federal ST N & E North AV Pittsburgh, PA 15212',
#   'OFFENSES': '9501 Bench Warrant',
#   'INCIDENTLOCATION': 'Federal ST & E North AV Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Allegheny Center',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2204',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00663235,
#   'Y': 40.45544902},
#  {'_id': 38,
#   'PK': '1975461',
#   'CCR': '16013937',
#   'AGE': 29,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-21T15:40:00',
#   'ARRESTLOCATION': '900 Block SECOND AV Pittsburgh, PA 15219',
#   'OFFENSES': '3925 Receiving Stolen Property. / 3929 Retail Theft. / 4106 Access Device Fraud',
#   'INCIDENTLOCATION': '800 Block Freeport RD Pittsburgh, PA 15215',
#   'INCIDENTNEIGHBORHOOD': 'Lincoln-Lemington-Belmar',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1201',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.89761421,
#   'Y': 40.48782354},
#  {'_id': 39,
#   'PK': '1975497',
#   'CCR': '16116633',
#   'AGE': 27,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-21T14:00:00',
#   'ARRESTLOCATION': '900 Block 2nd AV Pittsburgh, PA 15219',
#   'OFFENSES': '903 Criminal Conspiracy. / 1543 Driving While Operating Privilege is Suspended or Revoked. / 13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance',
#   'INCIDENTLOCATION': 'Reddour ST & Sampsonia ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Central Northside',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2206',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00833384,
#   'Y': 40.45749854},
#  {'_id': 40,
#   'PK': '1975502',
#   'CCR': '16146596',
#   'AGE': 13,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-13T11:00:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '3502 Burglary.',
#   'INCIDENTLOCATION': '1400 Block Lowrie ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Troy Hill-Herrs Island',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2406',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.98587703,
#   'Y': 40.46076942},
#  {'_id': 41,
#   'PK': '1974804',
#   'CCR': '16154582',
#   'AGE': 19,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-30T13:27:00',
#   'ARRESTLOCATION': '600 Block 1 st AV Pittsburgh, PA 15203',
#   'OFFENSES': '9093 Indirect Criminal Contempt',
#   'INCIDENTLOCATION': '50 Block S 16th ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '7',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -79.98782799,
#   'Y': 40.44901784},
#  {'_id': 42,
#   'PK': '1974841',
#   'CCR': '16153772',
#   'AGE': 52,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-17T08:00:00',
#   'ARRESTLOCATION': '1100 Block N St Clair ST Pittsburgh, PA 15206',
#   'OFFENSES': '9093 Indirect Criminal Contempt',
#   'INCIDENTLOCATION': '1100 Block N St Clair ST Pittsburgh, PA 15206',
#   'INCIDENTNEIGHBORHOOD': 'Highland Park',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1102',
#   'COUNCIL_DISTRICT': '7',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.92167799,
#   'Y': 40.4744501},
#  {'_id': 43,
#   'PK': '1975025',
#   'CCR': '16155685',
#   'AGE': 27,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-19T20:22:00',
#   'ARRESTLOCATION': 'Zone 3',
#   'OFFENSES': '3126(a)(1) Indecent assault without consent / 2709.1 Stalking Conduct or Repeatedly Acts Including Follows',
#   'INCIDENTLOCATION': 'Zone 3',
#   'INCIDENTNEIGHBORHOOD': None,
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': None,
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': None,
#   'Y': None},
#  {'_id': 44,
#   'PK': '1975096',
#   'CCR': '16115700',
#   'AGE': 40,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-01T09:30:00',
#   'ARRESTLOCATION': '100 Block S Diamond ST Mercer, PA 16137',
#   'OFFENSES': '3922 Theft by Deception. / 517.8(A1) Home Improvement Fraud',
#   'INCIDENTLOCATION': '700 Block Chautauqua CT Pittsburgh, PA 15214',
#   'INCIDENTNEIGHBORHOOD': 'Perry South',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2614',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.01785107,
#   'Y': 40.46388665},
#  {'_id': 45,
#   'PK': '1975194',
#   'CCR': '16090046',
#   'AGE': 21,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-13T21:10:00',
#   'ARRESTLOCATION': '900 Block Second AV Pittsburgh, PA 15208',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': '1200 Block Pineridge ST Pittsburgh, PA 15208',
#   'INCIDENTNEIGHBORHOOD': 'Homewood North',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1301',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.88981017,
#   'Y': 40.45900202},
#  {'_id': 46,
#   'PK': '1975206',
#   'CCR': '16161707',
#   'AGE': 16,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-13T09:15:00',
#   'ARRESTLOCATION': '900 Block Second AV Pittsburgh, PA 15219',
#   'OFFENSES': '903 Criminal Conspiracy. / 2901 Kidnapping. / 3702 Robbery of Motor Vehicle. / 6106 Firearms not to be Carried without a License. / 6110.1 Possesion of Firearm by Minor',
#   'INCIDENTLOCATION': '300 Block Mt Pleasant RD Pittsburgh, PA ',
#   'INCIDENTNEIGHBORHOOD': 'Northview Heights',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2609',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00304348,
#   'Y': 40.48235135},
#  {'_id': 47,
#   'PK': '1975268',
#   'CCR': '16161563',
#   'AGE': 22,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-09T20:45:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '6310.1 Selling Liquor to Minors / 601.04 (c) (2) Loudspeakers, etc 0700-2200 >75dB(c) 2200-0700 >75 dB(c)',
#   'INCIDENTLOCATION': '300 Block Oakland AV Pittsburgh, PA 15213',
#   'INCIDENTNEIGHBORHOOD': 'Central Oakland',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '405',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.95499045,
#   'Y': 40.43988746},
#  {'_id': 48,
#   'PK': '1975281',
#   'CCR': '16161285',
#   'AGE': 35,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-30T21:00:00',
#   'ARRESTLOCATION': '900 Block 2nd AV Pittsburgh, PA 15219',
#   'OFFENSES': '3701 Robbery.',
#   'INCIDENTLOCATION': '3700 Block Brighton RD Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Brighton Heights',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2708',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.03519475,
#   'Y': 40.48324656},
#  {'_id': 49,
#   'PK': '1975308',
#   'CCR': '16161900',
#   'AGE': 18,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-28T21:30:00',
#   'ARRESTLOCATION': '1200 Block Western AV Pittsburgh, PA 15233',
#   'OFFENSES': '2702 Aggravated Assault. / 2705 Recklessy Endangering Another Person. / 3701 Robbery.',
#   'INCIDENTLOCATION': '4500 Block Friendship AV Pittsburgh, PA 15224',
#   'INCIDENTNEIGHBORHOOD': 'Bloomfield',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '903',
#   'COUNCIL_DISTRICT': '7',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.95219916,
#   'Y': 40.46578525},
#  {'_id': 50,
#   'PK': '1975317',
#   'CCR': '16155934',
#   'AGE': 20,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-20T04:30:00',
#   'ARRESTLOCATION': '200 Block Renova ST Pittsburgh, PA 15207',
#   'OFFENSES': '2701 Simple Assault. / 3701 Robbery. / 2709(b) Stalking',
#   'INCIDENTLOCATION': '200 Block Renova ST Pittsburgh, PA 15207',
#   'INCIDENTNEIGHBORHOOD': 'Hazelwood',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1515',
#   'COUNCIL_DISTRICT': '5',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.93822561,
#   'Y': 40.40095544},
#  {'_id': 51,
#   'PK': '1975372',
#   'CCR': '16094906',
#   'AGE': 28,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-16T13:20:00',
#   'ARRESTLOCATION': '900 Block First AV Pittsburgh, PA 15219',
#   'OFFENSES': '3921 Theft by Unlawful Taking or Disposition.',
#   'INCIDENTLOCATION': 'Riverview Park Pittsburgh, PA 15214',
#   'INCIDENTNEIGHBORHOOD': 'Perry North',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2602',
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': None,
#   'Y': None},
#  {'_id': 52,
#   'PK': '1975519',
#   'CCR': '16168749',
#   'AGE': 17,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-07T13:38:00',
#   'ARRESTLOCATION': '600 Block 1ST AV PITTSBURGH, PA 15219',
#   'OFFENSES': '5503(a)(4) DISORDERLY CONDUCT - HAZARDOUS/PHYS. OFF',
#   'INCIDENTLOCATION': '900 Block BRUSHTON AV PITTSBURGH, PA 15208',
#   'INCIDENTNEIGHBORHOOD': 'Homewood North',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1302',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.88801848,
#   'Y': 40.45552397},
#  {'_id': 53,
#   'PK': '1974446',
#   'CCR': '14045292',
#   'AGE': 26,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T11:55:00',
#   'ARRESTLOCATION': '600 Block 1ST AV Pittsburgh, PA 15219',
#   'OFFENSES': '2701 Simple Assault. / 2706 Terroristic Threats.',
#   'INCIDENTLOCATION': '2500 Block Bedford AV Pittsburgh, PA 15219',
#   'INCIDENTNEIGHBORHOOD': 'Bedford Dwellings',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '509',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.97278341,
#   'Y': 40.45052409},
#  {'_id': 54,
#   'PK': '1975135',
#   'CCR': '16157080',
#   'AGE': 30,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-21T21:11:00',
#   'ARRESTLOCATION': '1000 Block Faulkner ST Pittsburgh, PA 15204',
#   'OFFENSES': '3502 Burglary. / 2701(a)(3) Simple Assault - Attempts by Physical Menace  / 3304(a)(5) CRIMINAL MISCHIEF - Intentionally Damages Real Or Personal Property Of Another',
#   'INCIDENTLOCATION': '1000 Block Tweed ST Pittsburgh, PA 15204',
#   'INCIDENTNEIGHBORHOOD': 'Sheraden',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2022',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.06250335,
#   'Y': 40.45661461},
#  {'_id': 55,
#   'PK': '1974953',
#   'CCR': '16151988',
#   'AGE': 45,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-14T15:38:00',
#   'ARRESTLOCATION': '6200 Block Penn AV Pittsburgh, PA 15206',
#   'OFFENSES': '3929 Retail Theft. / 5104 Resisting Arrest or Other Law Enforcement. / 3503.B1I DEF. TRESPASS ACTUAL COMMUNICATION',
#   'INCIDENTLOCATION': '6200 Block Penn AV Pittsburgh, PA 15206',
#   'INCIDENTNEIGHBORHOOD': 'East Liberty',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1115',
#   'COUNCIL_DISTRICT': '8',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.92271679,
#   'Y': 40.46059432},
#  {'_id': 56,
#   'PK': '1974512',
#   'CCR': '16145135',
#   'AGE': 19,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-04T22:15:00',
#   'ARRESTLOCATION': '1300 Block Chartiers AV Pittsburgh, PA 15220',
#   'OFFENSES': '3925 Receiving Stolen Property. / 1501 Drivers Required to be Licensed. / 3734 Driving without Lights to Avoid Identification or Arrest',
#   'INCIDENTLOCATION': '1300 Block Chartiers AV Pittsburgh, PA 15220',
#   'INCIDENTNEIGHBORHOOD': 'Elliott',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2020',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.04376167,
#   'Y': 40.44758823},
#  {'_id': 57,
#   'PK': '1974514',
#   'CCR': '16145510',
#   'AGE': None,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-05T12:45:00',
#   'ARRESTLOCATION': '1800 Block Broadway AV Pittsburgh, PA 15216',
#   'OFFENSES': '3304 Criminal Mischief. / 3503 Criminal Trespass / 4914 False Identification to Law Enforcement Authorities / 3921(a) Theft by Unlawful Taking or Disposition - Movable item',
#   'INCIDENTLOCATION': '1800 Block Broadway AV Pittsburgh, PA 15216',
#   'INCIDENTNEIGHBORHOOD': 'Beechview',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '1920',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.02576677,
#   'Y': 40.40779483},
#  {'_id': 58,
#   'PK': '1974709',
#   'CCR': '16149939',
#   'AGE': 21,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-11T18:12:00',
#   'ARRESTLOCATION': '2300 Block East Hills DR Pittsburgh, PA 15221',
#   'OFFENSES': '4910 Tampering with or Fabricating Physical Evidence. / 1301 Registration and Certificate of Title Required. / 7513 Restriction on Alcoholic Beverages - Open Container / 627.02(b) Possession or Smoking of a Small Amount of Marijuana',
#   'INCIDENTLOCATION': '2300 Block East Hills DR Pittsburgh, PA 15221',
#   'INCIDENTNEIGHBORHOOD': 'East Hills',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1306',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.87136146,
#   'Y': 40.45656464},
#  {'_id': 59,
#   'PK': '1974770',
#   'CCR': '16151444',
#   'AGE': 36,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-13T19:06:00',
#   'ARRESTLOCATION': 'Smithfield ST & Blvd Of The Allies Pittsburgh, PA 15222',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': 'Smithfield ST & Blvd Of The Allies Pittsburgh, PA 15222',
#   'INCIDENTNEIGHBORHOOD': 'Golden Triangle/Civic Arena',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '201',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -80.0001799,
#   'Y': 40.43777805},
#  {'_id': 60,
#   'PK': '1975509',
#   'CCR': '16167289',
#   'AGE': 37,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-23T16:40:00',
#   'ARRESTLOCATION': '900 Block 2ND AV Pittsburgh, PA 15219',
#   'OFFENSES': '3701 Robbery.',
#   'INCIDENTLOCATION': '800 Block Suismon ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99735506,
#   'Y': 40.45581482},
#  {'_id': 61,
#   'PK': '1975218',
#   'CCR': '16161466',
#   'AGE': 44,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-09T04:50:00',
#   'ARRESTLOCATION': '900 Block 2nd AV Pittsburgh, PA 15219',
#   'OFFENSES': '9015 Failure To Appear/Arrest on Attachment Order',
#   'INCIDENTLOCATION': 'Howard ST & E North AV Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Fineview',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2509',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99923238,
#   'Y': 40.4568392},
#  {'_id': 62,
#   'PK': '1975029',
#   'CCR': '16156204',
#   'AGE': 15,
#   'GENDER': 'F',
#   'RACE': 'H',
#   'ARRESTTIME': '2016-08-31T13:30:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15203',
#   'OFFENSES': '2707 Propulsion of Missiles  / 3304(a)(5) CRIMINAL MISCHIEF - Intentionally Damages Real Or Personal Property Of Another',
#   'INCIDENTLOCATION': '2600 Block Brownsville RD Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Carrick',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '2901',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.97880106,
#   'Y': 40.38544231},
#  {'_id': 63,
#   'PK': '1975031',
#   'CCR': '16154937',
#   'AGE': 35,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-18T20:24:00',
#   'ARRESTLOCATION': '700 Block Johnston AV Pittsburgh, PA 15207',
#   'OFFENSES': '4910 Tampering with or Fabricating Physical Evidence. / 6105(a)(1) Persons not to possess, use, manufacture, control, sell or transfer firearms: Former Convict enumerated in subsection (b) / 6106 Firearms not to be Carried without a License.',
#   'INCIDENTLOCATION': '700 Block Johnston AV Pittsburgh, PA 15207',
#   'INCIDENTNEIGHBORHOOD': 'Glen Hazel',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1504',
#   'COUNCIL_DISTRICT': '5',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.93341101,
#   'Y': 40.40578844},
#  {'_id': 64,
#   'PK': '1975032',
#   'CCR': '16154937',
#   'AGE': 29,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-18T20:24:00',
#   'ARRESTLOCATION': '700 Block Johnston AV Pittsburgh, PA 15207',
#   'OFFENSES': '3925 Receiving Stolen Property. / 6105(a)(1) Persons not to possess, use, manufacture, control, sell or transfer firearms: Former Convict enumerated in subsection (b) / 6106 Firearms not to be Carried without a License. / 6110.2 Possesion of Firearm with Altered Mfg. Number',
#   'INCIDENTLOCATION': '700 Block Johnston AV Pittsburgh, PA 15207',
#   'INCIDENTNEIGHBORHOOD': 'Glen Hazel',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1504',
#   'COUNCIL_DISTRICT': '5',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.93341101,
#   'Y': 40.40578844},
#  {'_id': 65,
#   'PK': '1975034',
#   'CCR': '16033848',
#   'AGE': 23,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-01T16:00:00',
#   'ARRESTLOCATION': '900 Block 2nd AV Pittsburgh, PA 15219',
#   'OFFENSES': '903 Criminal Conspiracy. / 2701 Simple Assault.',
#   'INCIDENTLOCATION': '1100 Block Buente ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Spring Hill-City View',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2620',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99554483,
#   'Y': 40.46661658},
#  {'_id': 66,
#   'PK': '1974457',
#   'CCR': '16121966',
#   'AGE': 37,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-22T18:15:00',
#   'ARRESTLOCATION': 'Zone 6',
#   'OFFENSES': '3123(a)(3) IDSI with unconscious person / 3123(a)(4) IDSI - drugs or intoxicants',
#   'INCIDENTLOCATION': 'Zone 6',
#   'INCIDENTNEIGHBORHOOD': None,
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': None,
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': None,
#   'Y': None},
#  {'_id': 67,
#   'PK': '1974460',
#   'CCR': '16131237',
#   'AGE': 45,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T10:15:00',
#   'ARRESTLOCATION': '900 Block 2ND AV Pittsburgh, PA 15219',
#   'OFFENSES': '903 Criminal Conspiracy. / 3929(a)(1) Retail Theft; takes possession of, carries away, or transfers displayed merchandise',
#   'INCIDENTLOCATION': '200 Block Atwood ST Pittsburgh, PA 15213',
#   'INCIDENTNEIGHBORHOOD': 'Central Oakland',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '405',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.95688887,
#   'Y': 40.44042041},
#  {'_id': 68,
#   'PK': '1974505',
#   'CCR': '16145555',
#   'AGE': 25,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-05T14:15:00',
#   'ARRESTLOCATION': '3200 Block Faronia ST Pittsburgh, PA 15204',
#   'OFFENSES': '907 Possessing Instruments of Crime. / 3304 Criminal Mischief. / 4910 Tampering with or Fabricating Physical Evidence.',
#   'INCIDENTLOCATION': '3200 Block Faronia ST Pittsburgh, PA 15204',
#   'INCIDENTNEIGHBORHOOD': 'Sheraden',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2022',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.06635734,
#   'Y': 40.45160189},
#  {'_id': 69,
#   'PK': '1974974',
#   'CCR': '16150703',
#   'AGE': 24,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-06T11:00:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': '100 Block Sheffield ST Pittsburgh, PA 15233',
#   'INCIDENTNEIGHBORHOOD': 'Fineview',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2509',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.01979575,
#   'Y': 40.45410332},
#  {'_id': 70,
#   'PK': '1974614',
#   'CCR': '16148627',
#   'AGE': 36,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-16T21:30:00',
#   'ARRESTLOCATION': '600 Block First AV Pittsburgh, PA 15219',
#   'OFFENSES': '2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury',
#   'INCIDENTLOCATION': '65 RT & McKees Rocks BRDG Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Marshall-Shadeland',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2715',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.04303594,
#   'Y': 40.47892402},
#  {'_id': 71,
#   'PK': '1974623',
#   'CCR': '16130258',
#   'AGE': 57,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-26T17:16:00',
#   'ARRESTLOCATION': 'Market SQ Pittsburgh, PA 15222',
#   'OFFENSES': '9015 Failure To Appear/Arrest on Attachment Order',
#   'INCIDENTLOCATION': '100 Block 5th AV Pittsburgh, PA 15222',
#   'INCIDENTNEIGHBORHOOD': 'Golden Triangle/Civic Arena',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '201',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -80.00287326,
#   'Y': 40.44140616},
#  {'_id': 72,
#   'PK': '1975063',
#   'CCR': '16157446',
#   'AGE': 22,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T13:30:00',
#   'ARRESTLOCATION': '900 Block Gibson ST Pittsburgh, PA 15220',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance / 7512 Criminal Use of Communication',
#   'INCIDENTLOCATION': '900 Block Gibson ST Pittsburgh, PA 15220',
#   'INCIDENTNEIGHBORHOOD': 'Elliott',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '2020',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.03820991,
#   'Y': 40.44423898},
#  {'_id': 73,
#   'PK': '1974834',
#   'CCR': '16153306',
#   'AGE': 25,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-16T15:20:00',
#   'ARRESTLOCATION': '300 Block Cedar AV Pittsburgh, PA 15212',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance',
#   'INCIDENTLOCATION': '300 Block Cedar AV Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00084389,
#   'Y': 40.45089272},
#  {'_id': 74,
#   'PK': '1975020',
#   'CCR': '16157206',
#   'AGE': 23,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T02:56:00',
#   'ARRESTLOCATION': 'Fountain ST & Sandusky ST N Pittsburgh, PA 15212',
#   'OFFENSES': '1543 Driving While Operating Privilege is Suspended or Revoked. / 4303 General Lighting Requirements. / 4703 Operation of Vehicle without Official Certif. of Inspection / 4706 Prohib. on Expend. for Emission Insp Prog.. / 13(a)(31) Marijuana: Possession Small Amount',
#   'INCIDENTLOCATION': 'Fountain ST & Sandusky ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Central Northside',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2206',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00553337,
#   'Y': 40.45897216},
#  {'_id': 75,
#   'PK': '1975021',
#   'CCR': '16157206',
#   'AGE': 22,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T02:56:00',
#   'ARRESTLOCATION': 'Fountain ST & Sandusky ST N Pittsburgh, PA 15212',
#   'OFFENSES': '9501 Bench Warrant',
#   'INCIDENTLOCATION': 'Fountain ST & Sandusky ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Central Northside',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2206',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.00553337,
#   'Y': 40.45897216},
#  {'_id': 76,
#   'PK': '1975037',
#   'CCR': '16157322',
#   'AGE': None,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-22T16:40:00',
#   'ARRESTLOCATION': '800 Block N Euclid AV Pittsburgh, PA 15206',
#   'OFFENSES': '3925 Receiving Stolen Property. / 1501 Drivers Required to be Licensed. / 3334 Turning Movements and Required Signals. / 13(a)(32) Paraphernalia - Use or Possession',
#   'INCIDENTLOCATION': '5800 Block Centre AV Pittsburgh, PA 15206',
#   'INCIDENTNEIGHBORHOOD': 'East Liberty',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1115',
#   'COUNCIL_DISTRICT': '8',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.93146655,
#   'Y': 40.45762754},
#  {'_id': 77,
#   'PK': '1975470',
#   'CCR': '16115249',
#   'AGE': 24,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-18T20:00:00',
#   'ARRESTLOCATION': '400 Block Ardmore BL Pittsburgh, PA 15221',
#   'OFFENSES': '9501 Bench Warrant',
#   'INCIDENTLOCATION': '1800 Block Watson ST Pittsburgh, PA 15219',
#   'INCIDENTNEIGHBORHOOD': 'Bluff',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '103',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98134515,
#   'Y': 40.43788568},
#  {'_id': 78,
#   'PK': '1975475',
#   'CCR': '16162261',
#   'AGE': 33,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-19T17:50:00',
#   'ARRESTLOCATION': '900 Block Second AV Pittsburgh, PA 15219',
#   'OFFENSES': '3925 Receiving Stolen Property.',
#   'INCIDENTLOCATION': '2300 Block Brownsville RD Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Carrick',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '2902',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98551986,
#   'Y': 40.38904931},
#  {'_id': 79,
#   'PK': '1974540',
#   'CCR': '16146636',
#   'AGE': 27,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-07T01:10:00',
#   'ARRESTLOCATION': '1500 Block E Carson ST Pittsburgh, PA 15203',
#   'OFFENSES': '5505 Public Drunkenness / 3503.B1I DEF. TRESPASS ACTUAL COMMUNICATION',
#   'INCIDENTLOCATION': '1500 Block E Carson ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98330671,
#   'Y': 40.42868483},
#  {'_id': 80,
#   'PK': '1974545',
#   'CCR': '16146642',
#   'AGE': 25,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-09T23:00:00',
#   'ARRESTLOCATION': '600 Block 1st AV Pittsburgh, PA 15219',
#   'OFFENSES': '3736 Reckless Driving / 3802(a)(1) DUI - General Impairment / 3802(c) DUI - Highest Rate of Alcohol - BAC >= .16%',
#   'INCIDENTLOCATION': '1800 Block Banksville RD Pittsburgh, PA 15216',
#   'INCIDENTNEIGHBORHOOD': 'Beechview',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '1920',
#   'COUNCIL_DISTRICT': '2',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.0322774,
#   'Y': 40.40892293},
#  {'_id': 81,
#   'PK': '1974561',
#   'CCR': '16146725',
#   'AGE': 48,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-07T03:37:00',
#   'ARRESTLOCATION': '1000 Block Sheffield ST Pittsburgh, PA 15233',
#   'OFFENSES': '4906 False Reports to Law Enforcement Authorities.',
#   'INCIDENTLOCATION': '1000 Block Sheffield ST Pittsburgh, PA 15233',
#   'INCIDENTNEIGHBORHOOD': 'Manchester',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2107',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -80.01979575,
#   'Y': 40.45410332},
#  {'_id': 82,
#   'PK': '1974760',
#   'CCR': '16149328',
#   'AGE': 30,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-10T21:20:00',
#   'ARRESTLOCATION': 'Frankstown AV & East Hills DR Pittsburgh, PA 15221',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession',
#   'INCIDENTLOCATION': 'Frankstown AV & East Hills DR Pittsburgh, PA 15221',
#   'INCIDENTNEIGHBORHOOD': 'East Hills',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1306',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.87041082,
#   'Y': 40.46117979},
#  {'_id': 83,
#   'PK': '1974769',
#   'CCR': '16151653',
#   'AGE': 42,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-14T01:01:00',
#   'ARRESTLOCATION': 'Silver Lake DR & Washington BL Pittsburgh, PA 15206',
#   'OFFENSES': '9501 Bench Warrant',
#   'INCIDENTLOCATION': 'Silver Lake DR & Washington BL Pittsburgh, PA 15206',
#   'INCIDENTNEIGHBORHOOD': 'Homewood West',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1207',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.90559538,
#   'Y': 40.46225948},
#  {'_id': 84,
#   'PK': '1974775',
#   'CCR': '16151710',
#   'AGE': 19,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-14T02:15:00',
#   'ARRESTLOCATION': '1000 Block Western AV Pittsburgh, PA 15233',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession / 13(a)(31) Marijuana: Possession Small Amount',
#   'INCIDENTLOCATION': '1000 Block Western AV NEW KENSINGTON, PA 15068',
#   'INCIDENTNEIGHBORHOOD': 'Outside County',
#   'INCIDENTZONE': 'OSC',
#   'INCIDENTTRACT': '6699',
#   'COUNCIL_DISTRICT': None,
#   'PUBLIC_WORKS_DIVISION': None,
#   'X': -79.73003325,
#   'Y': 40.58621354},
#  {'_id': 85,
#   'PK': '1975090',
#   'CCR': '16154461',
#   'AGE': 26,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-18T06:03:00',
#   'ARRESTLOCATION': '600 Block Elmbank ST Pittsburgh, PA 15226',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance',
#   'INCIDENTLOCATION': '600 Block Elmbank ST Pittsburgh, PA 15226',
#   'INCIDENTNEIGHBORHOOD': 'Brookline',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '1917',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.01608926,
#   'Y': 40.39948422},
#  {'_id': 86,
#   'PK': '1974821',
#   'CCR': '16147809',
#   'AGE': 28,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-08T19:52:00',
#   'ARRESTLOCATION': '2100 Block Brownsville RD Pittsburgh, PA 15210',
#   'OFFENSES': '2701 Simple Assault. / 2705 Recklessy Endangering Another Person. / 3304 Criminal Mischief. / 4304(a)(1) Endangering Welfare of Children.',
#   'INCIDENTLOCATION': '2100 Block Brownsville RD Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Carrick',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '2901',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98735091,
#   'Y': 40.39183252},
#  {'_id': 87,
#   'PK': '1975081',
#   'CCR': '16156737',
#   'AGE': 28,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-21T12:38:00',
#   'ARRESTLOCATION': '7500 Block Rosemary RD Pittsburgh, PA 15221',
#   'OFFENSES': '2706 Terroristic Threats. / 3304 Criminal Mischief. / 3502 Burglary.',
#   'INCIDENTLOCATION': '7500 Block Rosemary RD Pittsburgh, PA 15221',
#   'INCIDENTNEIGHBORHOOD': 'Point Breeze',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1406',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.89937036,
#   'Y': 40.44159885},
#  {'_id': 88,
#   'PK': '1975530',
#   'CCR': '16165929',
#   'AGE': 25,
#   'GENDER': 'F',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-03T04:40:00',
#   'ARRESTLOCATION': 'Bigelow SQ Pittsburgh, PA 15219',
#   'OFFENSES': '2701 Simple Assault.',
#   'INCIDENTLOCATION': 'Bigelow SQ Pittsburgh, PA 15219',
#   'INCIDENTNEIGHBORHOOD': 'Golden Triangle/Civic Arena',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '201',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '6',
#   'X': -79.99440381,
#   'Y': 40.44078618},
#  {'_id': 89,
#   'PK': '1975536',
#   'CCR': '16165979',
#   'AGE': 32,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-03T08:00:00',
#   'ARRESTLOCATION': '100 Block S 13th ST Pittsburgh, PA 15203',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession',
#   'INCIDENTLOCATION': '100 Block S 13th ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98545585,
#   'Y': 40.42704846},
#  {'_id': 90,
#   'PK': '1975133',
#   'CCR': '16158630',
#   'AGE': 33,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-05T17:24:00',
#   'ARRESTLOCATION': '1st AV & Blvd Of The Allies Pittsburgh, PA 15219',
#   'OFFENSES': '3925 Receiving Stolen Property. / 1543 Driving While Operating Privilege is Suspended or Revoked. / 3714 Careless Driving',
#   'INCIDENTLOCATION': '600 Block S 10th ST Pittsburgh, PA 15203',
#   'INCIDENTNEIGHBORHOOD': 'South Side Flats',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '1702',
#   'COUNCIL_DISTRICT': '3',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98852842,
#   'Y': 40.4265902},
#  {'_id': 91,
#   'PK': '1975273',
#   'CCR': '16157108',
#   'AGE': 22,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-21T22:02:00',
#   'ARRESTLOCATION': '6900 Block Frankstown AV Pittsburgh, PA 15208',
#   'OFFENSES': '3925 Receiving Stolen Property. / 5121 Escape. / 6105(a)(1) Persons not to possess, use, manufacture, control, sell or transfer firearms: Former Convict enumerated in subsection (b) / 6106 Firearms not to be Carried without a License.',
#   'INCIDENTLOCATION': '6900 Block Frankstown AV Pittsburgh, PA 15208',
#   'INCIDENTNEIGHBORHOOD': 'Homewood West',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1207',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.90425142,
#   'Y': 40.45803936},
#  {'_id': 92,
#   'PK': '1975276',
#   'CCR': '16157125',
#   'AGE': 24,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-21T23:28:00',
#   'ARRESTLOCATION': '300 Block Birmingham AV Pittsburgh, PA 15210',
#   'OFFENSES': '2706 Terroristic Threats. / 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury',
#   'INCIDENTLOCATION': '300 Block Birmingham AV Pittsburgh, PA 15210',
#   'INCIDENTNEIGHBORHOOD': 'Carrick',
#   'INCIDENTZONE': '3',
#   'INCIDENTTRACT': '2902',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.98401857,
#   'Y': 40.40279274},
#  {'_id': 93,
#   'PK': '1975384',
#   'CCR': '16029218',
#   'AGE': 32,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-09-01T03:45:00',
#   'ARRESTLOCATION': '900 Block 2nd AV Pittsburgh, PA 15219',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession',
#   'INCIDENTLOCATION': '800 Block Concord ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'East Allegheny',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2304',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99792377,
#   'Y': 40.45756351},
#  {'_id': 94,
#   'PK': '1975511',
#   'CCR': '16165050',
#   'AGE': 16,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-01T23:22:00',
#   'ARRESTLOCATION': '7300 Block Frankstown AV Pittsburgh, PA 15208',
#   'OFFENSES': '6106 Firearms not to be Carried without a License. / 13(a)(31) Marijuana: Possession Small Amount / 6110.1 Possesion of Firearm by Minor / 4914 False Identification to Law Enforcement Authorities',
#   'INCIDENTLOCATION': '7300 Block Frankstown AV Pittsburgh, PA 15208',
#   'INCIDENTNEIGHBORHOOD': 'Homewood North',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1302',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.89405819,
#   'Y': 40.45693837},
#  {'_id': 95,
#   'PK': '1975356',
#   'CCR': '16162844',
#   'AGE': 21,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-29T23:30:00',
#   'ARRESTLOCATION': '800 Block Sebring AV Pittsburgh, PA 15216',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance / 13(a)(31) Marijuana: Possession Small Amount',
#   'INCIDENTLOCATION': '800 Block Sebring AV Pittsburgh, PA 15216',
#   'INCIDENTNEIGHBORHOOD': 'Beechview',
#   'INCIDENTZONE': '6',
#   'INCIDENTTRACT': '1916',
#   'COUNCIL_DISTRICT': '4',
#   'PUBLIC_WORKS_DIVISION': '5',
#   'X': -80.02299777,
#   'Y': 40.41309915},
#  {'_id': 96,
#   'PK': '1975358',
#   'CCR': '16162854',
#   'AGE': 35,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-29T23:33:00',
#   'ARRESTLOCATION': '700 Block Brushton AV Pittsburgh, PA 15221',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance / 13(a)(30)* Delivery of Controlled Substance',
#   'INCIDENTLOCATION': '700 Block Brushton AV Pittsburgh, PA 15221',
#   'INCIDENTNEIGHBORHOOD': 'Homewood South',
#   'INCIDENTZONE': '5',
#   'INCIDENTTRACT': '1304',
#   'COUNCIL_DISTRICT': '9',
#   'PUBLIC_WORKS_DIVISION': '2',
#   'X': -79.88874138,
#   'Y': 40.45367526},
#  {'_id': 97,
#   'PK': '1974535',
#   'CCR': '16145596',
#   'AGE': 25,
#   'GENDER': 'F',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-08-05T15:26:00',
#   'ARRESTLOCATION': '5800 Block Forward AV Pittsburgh, PA 15217',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession',
#   'INCIDENTLOCATION': '5800 Block Forward AV Pittsburgh, PA 15217',
#   'INCIDENTNEIGHBORHOOD': 'Squirrel Hill South',
#   'INCIDENTZONE': '4',
#   'INCIDENTTRACT': '1408',
#   'COUNCIL_DISTRICT': '5',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.92335695,
#   'Y': 40.4295955},
#  {'_id': 98,
#   'PK': '1974941',
#   'CCR': '16155030',
#   'AGE': 34,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-18T22:46:00',
#   'ARRESTLOCATION': 'lamar ST & Williams RD Pittsburgh, PA 15212',
#   'OFFENSES': '13(a)(16) Possession of Controlled Substance',
#   'INCIDENTLOCATION': 'lamar ST & Williams RD Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Northview Heights',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2609',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99769601,
#   'Y': 40.4745937},
#  {'_id': 99,
#   'PK': '1974954',
#   'CCR': '16091081',
#   'AGE': 20,
#   'GENDER': 'M',
#   'RACE': 'B',
#   'ARRESTTIME': '2016-09-07T01:30:00',
#   'ARRESTLOCATION': '900 Block 2ND AV Pittsburgh, PA 15219',
#   'OFFENSES': '2706 Terroristic Threats. / 2701(a)(3) Simple Assault - Attempts by Physical Menace ',
#   'INCIDENTLOCATION': '2600 Block Centre AV Pittsburgh, PA 15219',
#   'INCIDENTNEIGHBORHOOD': 'Terrace Village',
#   'INCIDENTZONE': '2',
#   'INCIDENTTRACT': '510',
#   'COUNCIL_DISTRICT': '6',
#   'PUBLIC_WORKS_DIVISION': '3',
#   'X': -79.96841687,
#   'Y': 40.446533},
#  {'_id': 100,
#   'PK': '1974940',
#   'CCR': '16154303',
#   'AGE': 27,
#   'GENDER': 'M',
#   'RACE': 'W',
#   'ARRESTTIME': '2016-08-17T22:28:00',
#   'ARRESTLOCATION': '900 Block Mina ST Pittsburgh, PA 15212',
#   'OFFENSES': '2706 Terroristic Threats. / 5104 Resisting Arrest or Other Law Enforcement. / 5503(a)(3) DISORDERLY CONDUCT - OBSCENE LANG/GEST',
#   'INCIDENTLOCATION': '900 Block Mina ST Pittsburgh, PA 15212',
#   'INCIDENTNEIGHBORHOOD': 'Spring Hill-City View',
#   'INCIDENTZONE': '1',
#   'INCIDENTTRACT': '2620',
#   'COUNCIL_DISTRICT': '1',
#   'PUBLIC_WORKS_DIVISION': '1',
#   'X': -79.99918422,
#   'Y': 40.46894945}]

# %%
pd.json_normalize(data['result']['records'])
# Out:
#     _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0     1  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1     2  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2     3  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3     4  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4     5  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# ..  ...      ...       ...   ...    ...  ...                  ...
# 95   96  1975358  16162854  35.0      M    B  2016-08-29T23:33:00
# 96   97  1974535  16145596  25.0      F    B  2016-08-05T15:26:00
# 97   98  1974941  16155030  34.0      M    W  2016-08-18T22:46:00
# 98   99  1974954  16091081  20.0      M    B  2016-09-07T01:30:00
# 99  100  1974940  16154303  27.0      M    W  2016-08-17T22:28:00
#
#                                       ARRESTLOCATION  \
# 0          4700 Block Centre AV Pittsburgh, PA 15213
# 1   4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2         900 Block Freeport RD Fox Chapel, PA 15238
# 3        Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4          900 Block Woodlow ST Pittsburgh, PA 15205
# ..                                               ...
# 95        700 Block Brushton AV Pittsburgh, PA 15221
# 96        5800 Block Forward AV Pittsburgh, PA 15217
# 97       lamar ST & Williams RD Pittsburgh, PA 15212
# 98             900 Block 2ND AV Pittsburgh, PA 15219
# 99            900 Block Mina ST Pittsburgh, PA 15212
#
#                                              OFFENSES  \
# 0                                  3929 Retail Theft.
# 1        13(a)(16) Possession of Controlled Substance
# 2                                  3929 Retail Theft.
# 3   5503 Disorderly Conduct. / 5505 Public Drunken...
# 4   2702 Aggravated Assault. / 2705 Recklessy Enda...
# ..                                                ...
# 95  13(a)(16) Possession of Controlled Substance /...
# 96  13(a)(16) Possession of Controlled Substance /...
# 97       13(a)(16) Possession of Controlled Substance
# 98  2706 Terroristic Threats. / 2701(a)(3) Simple ...
# 99  2706 Terroristic Threats. / 5104 Resisting Arr...
#
#                                     INCIDENTLOCATION   INCIDENTNEIGHBORHOOD  \
# 0          4700 Block Centre AV Pittsburgh, PA 15213             Bloomfield
# 1   4200 Block Steubenville PKE Pittsburgh, PA 15205           Outside City
# 2         900 Block Freeport RD Fox Chapel, PA 15238               Westwood
# 3        Foreland ST & Cedar AV Pittsburgh, PA 15212         East Allegheny
# 4          900 Block Woodlow ST Pittsburgh, PA 15205        Crafton Heights
# ..                                               ...                    ...
# 95        700 Block Brushton AV Pittsburgh, PA 15221         Homewood South
# 96        5800 Block Forward AV Pittsburgh, PA 15217    Squirrel Hill South
# 97       lamar ST & Williams RD Pittsburgh, PA 15212      Northview Heights
# 98         2600 Block Centre AV Pittsburgh, PA 15219        Terrace Village
# 99            900 Block Mina ST Pittsburgh, PA 15212  Spring Hill-City View
#
#    INCIDENTZONE INCIDENTTRACT COUNCIL_DISTRICT PUBLIC_WORKS_DIVISION  \
# 0             5           804                8                     2
# 1           OSC          5599             None                  None
# 2             5          2811                9                     2
# 3             1          2304                1                     1
# 4             5          2814                2                     5
# ..          ...           ...              ...                   ...
# 95            5          1304                9                     2
# 96            4          1408                5                     3
# 97            1          2609                1                     1
# 98            2           510                6                     3
# 99            1          2620                1                     1
#
#             X          Y
# 0  -79.949277  40.452551
# 1  -80.088018  40.440136
# 2  -79.891803  40.486625
# 3  -80.001939  40.454080
# 4  -80.052204  40.445900
# ..        ...        ...
# 95 -79.888741  40.453675
# 96 -79.923357  40.429595
# 97 -79.997696  40.474594
# 98 -79.968417  40.446533
# 99 -79.999184  40.468949
#
# [100 rows x 17 columns]
